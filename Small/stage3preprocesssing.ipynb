# %%
import os
import pandas as pd
import numpy as np

# %%
#get list of files to rescrape
files = os.listdir(os.getcwd()+'/s2scrapedata')
files = [i for i in files if '__.csv' in i]

megadf = pd.DataFrame()

for f in files:
    tempdf = pd.read_csv('./s2scrapedata/'+f)
    megadf  = pd.concat((megadf,tempdf))

officialdf = pd.read_csv('../datadotgov_main.csv')
officialdf['ABN'] = officialdf['ABN'].astype(str)

# %%
#begin cleaning

megadf.index = megadf['ABN']
megadf = megadf.drop(['Website', 'Revenue', 'Expenses', 'Cause/s', 'Last_report_date', 'ref_religion','Unnamed: 0','ABN'], axis=1)

# %%
#add in interesting official data (namely no responsible persons, reg date and establishment date)

megadf = pd.merge(megadf,officialdf[["ABN",'Number_of_Responsible_Persons','Registration_Date','Date_Organisation_Established']],on='ABN',how='left')
megadf.to_csv('combined_scraped_list.csv')

# %%
#develop search/filter lists

# for free websites
freedomainlist = [  'webnode',
                    'wixsite',
                    'weebly',
                    'wordpress',
                    'hubspot',
                    'hs-sites',
                    'godaddy',
                    'site123',
                    'mozello',
                    'webstarts',
                    'jimdofree',
                    'ucraft',
                    'webflow',
                    'strinkingly',
                    'blog']
regexsearchstring = ''
for d in freedomainlist:
    regexsearchstring = (regexsearchstring+d+"|")[:-1]

webfilter_freesites     = megadf['website'].str.contains(pat=regexsearchstring,regex=True,na=False)
webfilter_free_orNone   = megadf['website'].str.contains(pat=regexsearchstring,regex=True,na=True)

# for religious reference
relfilter = megadf['religious_ref']==0

# for upto date reporting
recentreport_filter = megadf['lastreport'].str.contains('2021|2022',na=False)

# for state
statefilter = megadf['State']=='QLD'

# greater than one responsible person filter
teamsizefilter = megadf['Number_of_Responsible_Persons']>1

# name doesn't contain "trust" or "fund"
trustfundfilter  = ~megadf['Legal_Name'].str.contains('trust|fund|Trust|Fund|TRUST|FUND',regex=True,na=False)

# name doesn't contain "RSL", "Meals on Wheels" or'lifesave'
bigbusinessfilter  = ~megadf['Legal_Name'].str.contains('RSL|Returned And Services League|Returned Service League|Returned Services League|Rsl|Returned & Services League|Meals on Wheels|Meals On Wheels|Lifesave|Surf Life|Parents And Friends',regex=True,na=False)

# %%
filters = webfilter_free_orNone*relfilter*recentreport_filter*teamsizefilter*statefilter*trustfundfilter*bigbusinessfilter


megadf[filters].sort_values(by=['revenue'], ascending=False).iloc[91:110]
# Out:
#                ABN                                         Index_Link  \
# 13421  44825274317  https://www.acnc.gov.au/charity/charities/46af...
# 10762  11759339591  https://www.acnc.gov.au/charity/charities/18a8...
# 22780  51746985267  https://www.acnc.gov.au/charity/charities/4f17...
# 1188   95137744526  https://www.acnc.gov.au/charity/charities/da6e...
# 12616  67095850849  https://www.acnc.gov.au/charity/charities/ac74...
# 9384   88705721797  https://www.acnc.gov.au/charity/charities/729f...
# 13938  81609213323  https://www.acnc.gov.au/charity/charities/55a9...
# 3923   88491208849  https://www.acnc.gov.au/charity/charities/e0f5...
# 21028  21219909767  https://www.acnc.gov.au/charity/charities/640d...
# 7095   16613668009  https://www.acnc.gov.au/charity/charities/2913...
# 7492   17493208383  https://www.acnc.gov.au/charity/charities/c06e...
# 1572   44714074590  https://www.acnc.gov.au/charity/charities/a1b2...
# 18380  23832388550  https://www.acnc.gov.au/charity/charities/af3b...
# 15929  45716396152  https://www.acnc.gov.au/charity/charities/9ff1...
# 227    49108507823  https://www.acnc.gov.au/charity/charities/78ab...
# 5711   58126597804  https://www.acnc.gov.au/charity/charities/e779...
# 16882  94903145236  https://www.acnc.gov.au/charity/charities/70d9...
# 3764   76621205221  https://www.acnc.gov.au/charity/charities/77f8...
# 21530  37767348734  https://www.acnc.gov.au/charity/charities/f75f...
#
#                                               Legal_Name        Town/Suburb  \
# 13421                                 Home Of St Francis           Annerley
# 10762                 Stuartholme Sacre Coeur Associaton            Toowong
# 22780          Bonza Banga Charity Bbq's Street Outreach         Caboolture
# 1188   Kids R Us National Aog Children's Ministry Mov...         Springwood
# 12616                Seq Catchments Members' Association           Brisbane
# 9384                            Surat Hospital Auxiliary              Surat
# 13938                     Mutchilba Community Centre Inc           Dimbulah
# 3923                           Kingsley College P&F INC.          Berserker
# 21028                        Mackay Woodturners Assn Inc             Mackay
# 7095                     Charleville Airfield Museum Ltd        Charleville
# 7492   Forest Lake College Parents' And Friends' Asso...        Forest Lake
# 1572                                   ARAFMI CAIRNS INC           Bungalow
# 18380  Institution of Surveyors Australia (Queensland...            Kenmore
# 15929                 Wildlife Rescue South Burnett Inc.         Moondooner
# 227                            Bali Street Kids Home Inc         Noosaville
# 5711                             Mullen Bun Goon Limited    East Palmerston
# 16882                           Woodgate Men's Shed Inc.           Woodgate
# 3764      Farmers Health Promotion Collaborative Limited     Pinjarra Hills
# 21530       Gladstone Hospital Auxiliary Association Inc  Gladstone Central
#
#       State      Status   Size website  revenue  expenses  \
# 13421   QLD  Registered  Small     NaN  42144.0   36000.0
# 10762   QLD  Registered  Small     NaN  42083.0   30632.0
# 22780   QLD  Registered  Small     NaN  42000.0   38000.0
# 1188    QLD  Registered  Small     NaN  41030.0   80086.0
# 12616   QLD  Registered  Small     NaN  40008.0   40008.0
# 9384    QLD  Registered  Small     NaN  39039.0    9996.0
# 13938   QLD  Registered  Small     NaN  38675.0   39101.0
# 3923    QLD  Registered  Small     NaN  38009.0    1792.0
# 21028   QLD  Registered  Small     NaN  37033.0   22110.0
# 7095    QLD  Registered  Small     NaN  37008.0   37747.0
# 7492    QLD  Registered  Small     NaN  35895.0   40920.0
# 1572    QLD  Registered  Small     NaN  34787.0   34529.0
# 18380   QLD  Registered  Small     NaN  34582.0    3844.0
# 15929   QLD  Registered  Small     NaN  33562.0   36446.0
# 227     QLD  Registered  Small     NaN  32195.0   19309.0
# 5711    QLD  Registered  Small     NaN  30856.0   37662.0
# 16882   QLD  Registered  Small     NaN  30138.0   29411.0
# 3764    QLD  Registered  Small     NaN  30000.0    4777.0
# 21530   QLD  Registered  Small     NaN  29769.0   12573.0
#
#                                                   causes   lastreport  \
# 13421  Adults - aged 25 to under 65; Adults - aged 65...   6 Jun 2022
# 10762  Adults - aged 25 to under 65; Children - aged ...  15 Jun 2022
# 22780  Adults - aged 25 to under 65; People at risk o...   8 Apr 2022
# 1188                       Children - aged 6 to under 15  17 Feb 2022
# 12616                     General community in Australia  29 Jan 2022
# 9384                                            Families  27 Jan 2022
# 13938  Families; General community in Australia; Peop...   6 Apr 2021
# 3923   Children - aged 6 to under 15; Youth - 15 to u...  12 Jul 2022
# 21028  Adults - aged 25 to under 65; Adults - aged 65...   7 Feb 2022
# 7095   Families; People in rural/regional/remote comm...   7 Apr 2022
# 7492   Children - aged 6 to under 15; Early childhood...   3 May 2022
# 1572   Aboriginal and Torres Strait Islander people; ...   4 Dec 2021
# 18380                                                NaN  28 Jan 2022
# 15929  Aboriginal and Torres Strait Islander people; ...  18 Jan 2022
# 227    Children - aged 6 to under 15; Early childhood...  23 Jun 2022
# 5711   Aboriginal and Torres Strait Islander people; ...  12 Dec 2021
# 16882  Adults - aged 65 and over; Females; Males; Oth...  13 May 2022
# 3764   Adults - aged 25 to under 65; Adults - aged 65...   3 Jan 2022
# 21530  Aboriginal and Torres Strait Islander people; ...   1 Apr 2022
#
#        religious_ref  Number_of_Responsible_Persons Registration_Date  \
# 13421            0.0                            2.0        03/12/2012
# 10762            0.0                            5.0        03/12/2012
# 22780            0.0                            7.0        03/12/2012
# 1188             0.0                            2.0        03/12/2012
# 12616            0.0                            6.0        03/12/2012
# 9384             0.0                            3.0        03/12/2012
# 13938            0.0                            5.0        03/12/2012
# 3923             0.0                            3.0        03/12/2012
# 21028            0.0                            3.0        03/12/2012
# 7095             0.0                            7.0        08/08/2016
# 7492             0.0                            2.0        03/12/2012
# 1572             0.0                            3.0        03/12/2012
# 18380            0.0                            4.0        03/12/2012
# 15929            0.0                            5.0        30/08/2018
# 227              0.0                            3.0        03/12/2012
# 5711             0.0                            8.0        23/01/2020
# 16882            0.0                            4.0        03/12/2012
# 3764             0.0                            6.0        08/11/2017
# 21530            0.0                            2.0        03/12/2012
#
#       Date_Organisation_Established
# 13421                    01/01/1974
# 10762                    01/01/1926
# 22780                    01/01/2007
# 1188                     01/01/1996
# 12616                    01/01/2009
# 9384                     01/01/1959
# 13938                    01/01/1993
# 3923                     01/07/2010
# 21028                    01/01/1987
# 7095                     14/07/2016
# 7492                     01/01/1994
# 1572                     01/01/1994
# 18380                    01/01/1988
# 15929                    22/02/2018
# 227                      01/01/2008
# 5711                     18/07/2007
# 16882                           NaN
# 3764                     06/09/2017
# 21530                    01/01/1958
